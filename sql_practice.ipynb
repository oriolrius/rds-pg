# %% [markdown]
# # PostgreSQL SQL Practice
#
# This notebook connects to a PostgreSQL RDS database for SQL practice.

# %%
# Suppress jupysql warnings (Python 3.13 compatibility)
import warnings
warnings.filterwarnings("ignore", category=SyntaxWarning)

# Load environment variables
import os
from urllib.parse import quote_plus
from dotenv import load_dotenv

load_dotenv()

DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT", "5432")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = quote_plus(os.getenv("DB_PASSWORD"))  # URL-encode special chars
DB_NAME = os.getenv("DB_NAME")

# Set DATABASE_URL for jupysql auto-detection
os.environ["DATABASE_URL"] = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

print(f"Connecting to: {DB_HOST}:{DB_PORT}/{DB_NAME}")

# %%
# Load SQL magic
# %load_ext sql
# %config SqlMagic.displaylimit = 50
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Connect to PostgreSQL
from sqlalchemy import create_engine
engine = create_engine(os.environ["DATABASE_URL"])
# %sql engine --alias postgres

# %% [markdown]
# ## Check Connection
#
# Verify we're connected to PostgreSQL:

# %%
# %%sql
# SELECT version();
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 1 rows affected.
# +---------------------------------------------------------------------------------------------------+
# |                                              version                                              |
# +---------------------------------------------------------------------------------------------------+
# | PostgreSQL 15.15 on x86_64-pc-linux-gnu, compiled by x86_64-pc-linux-gnu-gcc (GCC) 12.4.0, 64-bit |
# +---------------------------------------------------------------------------------------------------+

# %% [markdown]
# ## Create Sample Table

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS users (
#     id SERIAL PRIMARY KEY,
#     name VARCHAR(100) NOT NULL,
#     email VARCHAR(100) UNIQUE NOT NULL,
#     age INTEGER,
#     city VARCHAR(50),
#     created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# ++
# ||
# ++
# ++

# %% [markdown]
# ## Insert Sample Data

# %%
# %%sql
# INSERT INTO users (name, email, age, city) VALUES
#     ('Alice Smith', 'alice@example.com', 28, 'Barcelona'),
#     ('Bob Johnson', 'bob@example.com', 35, 'Madrid'),
#     ('Carol White', 'carol@example.com', 42, 'Barcelona'),
#     ('David Brown', 'david@example.com', 31, 'Valencia'),
#     ('Eva Garcia', 'eva@example.com', 25, 'Madrid')
# ON CONFLICT (email) DO NOTHING;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 5 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ---
#
# # SQL Practice Exercises
#
# ## 1. SELECT Basics

# %%
# %%sql
# -- Select all users
# SELECT * FROM users;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 5 rows affected.
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | id |     name    |       email       | age |    city   |         created_at         |
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | 1  | Alice Smith | alice@example.com |  28 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 2  | Bob Johnson |  bob@example.com  |  35 |   Madrid  | 2026-01-27 16:33:42.131708 |
# | 3  | Carol White | carol@example.com |  42 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 4  | David Brown | david@example.com |  31 |  Valencia | 2026-01-27 16:33:42.131708 |
# | 5  |  Eva Garcia |  eva@example.com  |  25 |   Madrid  | 2026-01-27 16:33:42.131708 |
# +----+-------------+-------------------+-----+-----------+----------------------------+

# %%
# %%sql
# -- Select specific columns
# SELECT name, email FROM users;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 5 rows affected.
# +-------------+-------------------+
# |     name    |       email       |
# +-------------+-------------------+
# | Alice Smith | alice@example.com |
# | Bob Johnson |  bob@example.com  |
# | Carol White | carol@example.com |
# | David Brown | david@example.com |
# |  Eva Garcia |  eva@example.com  |
# +-------------+-------------------+

# %% [markdown]
# ## 2. WHERE Clause

# %%
# %%sql
# -- Filter by city
# SELECT * FROM users WHERE city = 'Barcelona';
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 2 rows affected.
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | id |     name    |       email       | age |    city   |         created_at         |
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | 1  | Alice Smith | alice@example.com |  28 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 3  | Carol White | carol@example.com |  42 | Barcelona | 2026-01-27 16:33:42.131708 |
# +----+-------------+-------------------+-----+-----------+----------------------------+

# %%
# %%sql
# -- Filter by age range
# SELECT * FROM users WHERE age >= 30;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 3 rows affected.
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | id |     name    |       email       | age |    city   |         created_at         |
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | 2  | Bob Johnson |  bob@example.com  |  35 |   Madrid  | 2026-01-27 16:33:42.131708 |
# | 3  | Carol White | carol@example.com |  42 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 4  | David Brown | david@example.com |  31 |  Valencia | 2026-01-27 16:33:42.131708 |
# +----+-------------+-------------------+-----+-----------+----------------------------+

# %%
# %%sql
# -- Multiple conditions
# SELECT * FROM users WHERE city = 'Madrid' AND age < 40;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 2 rows affected.
# +----+-------------+-----------------+-----+--------+----------------------------+
# | id |     name    |      email      | age |  city  |         created_at         |
# +----+-------------+-----------------+-----+--------+----------------------------+
# | 2  | Bob Johnson | bob@example.com |  35 | Madrid | 2026-01-27 16:33:42.131708 |
# | 5  |  Eva Garcia | eva@example.com |  25 | Madrid | 2026-01-27 16:33:42.131708 |
# +----+-------------+-----------------+-----+--------+----------------------------+

# %% [markdown]
# ## 3. ORDER BY

# %%
# %%sql
# -- Order by age descending
# SELECT * FROM users ORDER BY age DESC;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 5 rows affected.
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | id |     name    |       email       | age |    city   |         created_at         |
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | 3  | Carol White | carol@example.com |  42 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 2  | Bob Johnson |  bob@example.com  |  35 |   Madrid  | 2026-01-27 16:33:42.131708 |
# | 4  | David Brown | david@example.com |  31 |  Valencia | 2026-01-27 16:33:42.131708 |
# | 1  | Alice Smith | alice@example.com |  28 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 5  |  Eva Garcia |  eva@example.com  |  25 |   Madrid  | 2026-01-27 16:33:42.131708 |
# +----+-------------+-------------------+-----+-----------+----------------------------+

# %% [markdown]
# ## 4. Aggregate Functions

# %%
# %%sql
# -- Count users
# SELECT COUNT(*) as total_users FROM users;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 1 rows affected.
# +-------------+
# | total_users |
# +-------------+
# |      5      |
# +-------------+

# %%
# %%sql
# -- Average age
# SELECT AVG(age) as average_age FROM users;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 1 rows affected.
# +---------------------+
# |     average_age     |
# +---------------------+
# | 32.2000000000000000 |
# +---------------------+

# %%
# %%sql
# -- Group by city
# SELECT city, COUNT(*) as user_count, AVG(age) as avg_age
# FROM users
# GROUP BY city
# ORDER BY user_count DESC;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 3 rows affected.
# +-----------+------------+---------------------+
# |    city   | user_count |       avg_age       |
# +-----------+------------+---------------------+
# | Barcelona |     2      | 35.0000000000000000 |
# |   Madrid  |     2      | 30.0000000000000000 |
# |  Valencia |     1      | 31.0000000000000000 |
# +-----------+------------+---------------------+

# %% [markdown]
# ## 5. UPDATE

# %%
# %%sql
# -- Update a user's city
# UPDATE users SET city = 'Sevilla' WHERE name = 'David Brown';
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# -- Verify the update
# SELECT * FROM users WHERE name = 'David Brown';
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 1 rows affected.
# +----+-------------+-------------------+-----+---------+----------------------------+
# | id |     name    |       email       | age |   city  |         created_at         |
# +----+-------------+-------------------+-----+---------+----------------------------+
# | 4  | David Brown | david@example.com |  31 | Sevilla | 2026-01-27 16:33:42.131708 |
# +----+-------------+-------------------+-----+---------+----------------------------+

# %% [markdown]
# ## 6. LIKE Pattern Matching

# %%
# %%sql
# -- Find users whose name contains 'a'
# SELECT * FROM users WHERE name ILIKE '%a%';
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# 4 rows affected.
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | id |     name    |       email       | age |    city   |         created_at         |
# +----+-------------+-------------------+-----+-----------+----------------------------+
# | 1  | Alice Smith | alice@example.com |  28 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 3  | Carol White | carol@example.com |  42 | Barcelona | 2026-01-27 16:33:42.131708 |
# | 5  |  Eva Garcia |  eva@example.com  |  25 |   Madrid  | 2026-01-27 16:33:42.131708 |
# | 4  | David Brown | david@example.com |  31 |  Sevilla  | 2026-01-27 16:33:42.131708 |
# +----+-------------+-------------------+-----+-----------+----------------------------+

# %% [markdown]
# ---
#
# ## Cleanup (Optional)
#
# Run this to drop the table when done:

# %%
# %%sql
# DROP TABLE IF EXISTS users;
# Out:
# Running query in 'postgresql://postgres:***@postgres-rds-stack-postgres.ch8isoyag12f.eu-west-1.rds.amazonaws.com:5432/mydb'
# ++
# ||
# ++
# ++
