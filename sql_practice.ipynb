# %% [markdown]
# # PostgreSQL SQL Practice
#
# This notebook connects to a PostgreSQL RDS database for SQL practice.

# %%
# Suppress jupysql warnings (Python 3.13 compatibility)
import warnings
warnings.filterwarnings("ignore", category=SyntaxWarning)

# Load environment variables and connect to database
import os
from dotenv import load_dotenv

load_dotenv()

DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT", "5432")
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_NAME = os.getenv("DB_NAME")

print(f"Connecting to: {DB_HOST}:{DB_PORT}/{DB_NAME}")

# %%
# Load SQL magic
# %load_ext sql
# %config SqlMagic.displaylimit = 50
# Out:
# /home/oriol/esade/rds-pg/.venv/lib/python3.13/site-packages/sql/parse.py:338: SyntaxWarning: invalid escape sequence '\:'
#   """
# /home/oriol/esade/rds-pg/.venv/lib/python3.13/site-packages/sql/parse.py:368: SyntaxWarning: invalid escape sequence '\:'
#   """
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml

# %%
# Connect to PostgreSQL
# %sql postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}

# %% [markdown]
# ## Check Connection
#
# Verify we're connected to PostgreSQL:

# %%
# %%sql
# SELECT version();

# %% [markdown]
# ## Create Sample Table

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS users (
#     id SERIAL PRIMARY KEY,
#     name VARCHAR(100) NOT NULL,
#     email VARCHAR(100) UNIQUE NOT NULL,
#     age INTEGER,
#     city VARCHAR(50),
#     created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );

# %% [markdown]
# ## Insert Sample Data

# %%
# %%sql
# INSERT INTO users (name, email, age, city) VALUES
#     ('Alice Smith', 'alice@example.com', 28, 'Barcelona'),
#     ('Bob Johnson', 'bob@example.com', 35, 'Madrid'),
#     ('Carol White', 'carol@example.com', 42, 'Barcelona'),
#     ('David Brown', 'david@example.com', 31, 'Valencia'),
#     ('Eva Garcia', 'eva@example.com', 25, 'Madrid')
# ON CONFLICT (email) DO NOTHING;

# %% [markdown]
# ---
#
# # SQL Practice Exercises
#
# ## 1. SELECT Basics

# %%
# %%sql
# -- Select all users
# SELECT * FROM users;

# %%
# %%sql
# -- Select specific columns
# SELECT name, email FROM users;

# %% [markdown]
# ## 2. WHERE Clause

# %%
# %%sql
# -- Filter by city
# SELECT * FROM users WHERE city = 'Barcelona';

# %%
# %%sql
# -- Filter by age range
# SELECT * FROM users WHERE age >= 30;

# %%
# %%sql
# -- Multiple conditions
# SELECT * FROM users WHERE city = 'Madrid' AND age < 40;

# %% [markdown]
# ## 3. ORDER BY

# %%
# %%sql
# -- Order by age descending
# SELECT * FROM users ORDER BY age DESC;

# %% [markdown]
# ## 4. Aggregate Functions

# %%
# %%sql
# -- Count users
# SELECT COUNT(*) as total_users FROM users;

# %%
# %%sql
# -- Average age
# SELECT AVG(age) as average_age FROM users;

# %%
# %%sql
# -- Group by city
# SELECT city, COUNT(*) as user_count, AVG(age) as avg_age
# FROM users
# GROUP BY city
# ORDER BY user_count DESC;

# %% [markdown]
# ## 5. UPDATE

# %%
# %%sql
# -- Update a user's city
# UPDATE users SET city = 'Sevilla' WHERE name = 'David Brown';

# %%
# %%sql
# -- Verify the update
# SELECT * FROM users WHERE name = 'David Brown';

# %% [markdown]
# ## 6. LIKE Pattern Matching

# %%
# %%sql
# -- Find users whose name contains 'a'
# SELECT * FROM users WHERE name ILIKE '%a%';

# %% [markdown]
# ---
#
# ## Your Turn!
#
# Write your own SQL queries below:

# %%
# %%sql
# -- Your query here

# %% [markdown]
# ---
#
# ## Cleanup (Optional)
#
# Run this to drop the table when done:

# %%
# %%sql
# -- DROP TABLE IF EXISTS users;
